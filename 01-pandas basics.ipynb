# %% [markdown]
# # Pandas basics

# %%
# !ls
# Out:
# __MACOSX
# 01-pandas basics.ipynb
# continent_facts.csv
# countries.csv

# %%
# !pip install --quiet pandas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
import requests

# %%
#press tab to autofill your command
pd.read_csv("countries.csv")
# Out:
#                  country   continent  life_expectancy  population  \
# 0            Afghanistan        Asia           54.863    22856302
# 1                Albania      Europe           74.200     3071856
# 2                Algeria      Africa           68.963    30533827
# 3                 Angola      Africa           45.234    13926373
# 4    Antigua and Barbuda  N. America           73.544       77656
# ..                   ...         ...              ...         ...
# 183              Vietnam        Asia           73.777    78758010
# 184   West Bank and Gaza        Asia           70.929     3198560
# 185          Yemen, Rep.        Asia           60.404    17723186
# 186               Zambia      Africa           41.802    10201562
# 187             Zimbabwe      Africa           43.976    12509477
#
#               gdp
# 0     15153728226
# 1     12886435920
# 2    155661450046
# 3     34063908358
# 4       989182128
# ..            ...
# 183  124201381770
# ...

# %%
df = pd.read_csv("countries.csv")
df
# Out:
#                  country   continent  life_expectancy  population  \
# 0            Afghanistan        Asia           54.863    22856302
# 1                Albania      Europe           74.200     3071856
# 2                Algeria      Africa           68.963    30533827
# 3                 Angola      Africa           45.234    13926373
# 4    Antigua and Barbuda  N. America           73.544       77656
# ..                   ...         ...              ...         ...
# 183              Vietnam        Asia           73.777    78758010
# 184   West Bank and Gaza        Asia           70.929     3198560
# 185          Yemen, Rep.        Asia           60.404    17723186
# 186               Zambia      Africa           41.802    10201562
# 187             Zimbabwe      Africa           43.976    12509477
#
#               gdp
# 0     15153728226
# 1     12886435920
# 2    155661450046
# 3     34063908358
# 4       989182128
# ..            ...
# 183  124201381770
# ...

# %%
#this is going to give me the first five rows
df.head()
# Out:
#                country   continent  life_expectancy  population           gdp
# 0          Afghanistan        Asia           54.863    22856302   15153728226
# 1              Albania      Europe           74.200     3071856   12886435920
# 2              Algeria      Africa           68.963    30533827  155661450046
# 3               Angola      Africa           45.234    13926373   34063908358
# 4  Antigua and Barbuda  N. America           73.544       77656     989182128

# %%
#this is going to give you the last five rows
df.tail()
# Out:
#                 country continent  life_expectancy  population           gdp
# 183             Vietnam      Asia           73.777    78758010  124201381770
# 184  West Bank and Gaza      Asia           70.929     3198560   24264276160
# 185         Yemen, Rep.      Asia           60.404    17723186   39292303362
# 186              Zambia    Africa           41.802    10201562   10558616670
# 187            Zimbabwe    Africa           43.976    12509477    9319560365

# %%
#if you don't know what something does after having your choices shown with tab (after the period ".")
#hold shift + press tab after df.last for example

# %%
#this ugly output is called a series, but the pretty one above is called dataframe
df['life_expectancy']
# Out:
# 0      54.863
# 1      74.200
# 2      68.963
# 3      45.234
# 4      73.544
#         ...
# 183    73.777
# 184    70.929
# 185    60.404
# 186    41.802
# 187    43.976
# Name: life_expectancy, Length: 188, dtype: float64

# %%
#if we wanted to call a column with two words as a name you can't with period only brackets
df.population
# Out:
# 0      22856302
# 1       3071856
# 2      30533827
# 3      13926373
# 4         77656
#          ...
# 183    78758010
# 184     3198560
# 185    17723186
# 186    10201562
# 187    12509477
# Name: population, Length: 188, dtype: int64

# %%
#by default is from lowest to highest
df.sort_values('life_expectancy')
# Out:
#                   country continent  life_expectancy  population  \
# 147          Sierra Leone    Africa           38.123     4143115
# 186                Zambia    Africa           41.802    10201562
# 31   Central African Rep.    Africa           43.727     3701607
# 187              Zimbabwe    Africa           43.976    12509477
# 3                  Angola    Africa           45.234    13926373
# ..                    ...       ...              ...         ...
# 160                Sweden    Europe           79.840     8860153
# 7               Australia   Oceania           79.930    19164351
# 161           Switzerland    Europe           79.990     7167908
# 72       Hong Kong, China      Asia           80.361     6783317
# 83                  Japan      Asia           81.350   125720310
#
#                gdp
# 147     2141990455
# 186    10558616670
# 31      2820624534
# 187     9319560365
# 3      34063908358
# ..             ...
# 160   253754781920
# 7     560384787591
# ...

# %%
#to rank from highest to lowest
df.sort_values('life_expectancy', ascending=False)
# Out:
#                   country continent  life_expectancy  population  \
# 83                  Japan      Asia           81.350   125720310
# 72       Hong Kong, China      Asia           80.361     6783317
# 161           Switzerland    Europe           79.990     7167908
# 7               Australia   Oceania           79.930    19164351
# 160                Sweden    Europe           79.840     8860153
# ..                    ...       ...              ...         ...
# 3                  Angola    Africa           45.234    13926373
# 187              Zimbabwe    Africa           43.976    12509477
# 31   Central African Rep.    Africa           43.727     3701607
# 186                Zambia    Africa           41.802    10201562
# 147          Sierra Leone    Africa           38.123     4143115
#
#                gdp
# 83   3590446333290
# 72    203309577124
# 161   246475684488
# 7     560384787591
# 160   253754781920
# ..             ...
# 3      34063908358
# 187     9319560365
# ...

# %%
df[['country', 'life_expectancy']]
# Out:
#                  country  life_expectancy
# 0            Afghanistan           54.863
# 1                Albania           74.200
# 2                Algeria           68.963
# 3                 Angola           45.234
# 4    Antigua and Barbuda           73.544
# ..                   ...              ...
# 183              Vietnam           73.777
# 184   West Bank and Gaza           70.929
# 185          Yemen, Rep.           60.404
# 186               Zambia           41.802
# 187             Zimbabwe           43.976
#
# [188 rows x 2 columns]

# %%
#EVERYTHING THAT YOU DO HERE DOES NOT AFFECT THE ORIGINAL DATAFRAME UNLESS I SAY SO
#I CAN ADD ANYTHING 
#if you put inpalce=True it will affect the dataframe, but don't ever do it

# %%
#this says sort everything by life expectancy and then give me the first 10 rows
df.sort_values('life_expectancy', ascending=False).head(10)

#if it was:
#df.head(10).sort_values('life_expectancy', ascending=False) it would mean: from the dataframe i want the first 10 rows and then sort them by life expectancy
# Out:
#               country   continent  life_expectancy  population            gdp
# 83              Japan        Asia           81.350   125720310  3590446333290
# 72   Hong Kong, China        Asia           80.361     6783317   203309577124
# 161       Switzerland      Europe           79.990     7167908   246475684488
# 7           Australia     Oceania           79.930    19164351   560384787591
# 160            Sweden      Europe           79.840     8860153   253754781920
# 81              Italy      Europe           79.730    56986329  1547748695640
# 74            Iceland      Europe           79.720      281210     8743381320
# 29             Canada  N. America           79.410    30667365   995094659520
# 155             Spain      Europe           79.340    40288457   943152778370
# 57             France      Europe           79.230    59047795  1690892657620

# %%
#to call the Asia continent
df[df['continent'] == 'Asia']
# Out:
#                   country continent  life_expectancy  population  \
# 0             Afghanistan      Asia           54.863    22856302
# 11                Bahrain      Asia           74.497      638193
# 12             Bangladesh      Asia           65.309   129592275
# 18                 Bhutan      Asia           60.307      571262
# 23                 Brunei      Asia           75.927      327036
# 27               Cambodia      Asia           62.030    12446949
# 34                  China      Asia           72.124  1269116737
# 72       Hong Kong, China      Asia           80.361     6783317
# 75                  India      Asia           62.129  1053898107
# 76              Indonesia      Asia           67.289   213395411
# 77                   Iran      Asia           69.611    65342319
# 78                   Iraq      Asia           70.845    23857458
# 80                 Israel      Asia           78.750     6014953
# ...

# %%
df.sort_values('life_expectancy', ascending=False).head(10)
# Out:
#               country   continent  life_expectancy  population            gdp
# 83              Japan        Asia           81.350   125720310  3590446333290
# 72   Hong Kong, China        Asia           80.361     6783317   203309577124
# 161       Switzerland      Europe           79.990     7167908   246475684488
# 7           Australia     Oceania           79.930    19164351   560384787591
# 160            Sweden      Europe           79.840     8860153   253754781920
# 81              Italy      Europe           79.730    56986329  1547748695640
# 74            Iceland      Europe           79.720      281210     8743381320
# 29             Canada  N. America           79.410    30667365   995094659520
# 155             Spain      Europe           79.340    40288457   943152778370
# 57             France      Europe           79.230    59047795  1690892657620

# %%
#every country in asia with life expectancy over 75
df[(df['life_expectancy'] > 75) & (df['continent'] == 'Asia')]
#for specific country name 
#df[df['country'] == 'Brunei']
# Out:
#               country continent  life_expectancy  population            gdp
# 23             Brunei      Asia           75.927      327036    15704268720
# 72   Hong Kong, China      Asia           80.361     6783317   203309577124
# 80             Israel      Asia           78.750     6014953   137345436802
# 83              Japan      Asia           81.350   125720310  3590446333290
# 89        Korea, Rep.      Asia           76.114    45987624   781559669880
# 100      Macao, China      Asia           77.627      431867     9722189904
# 135             Qatar      Asia           76.680      590957    35690257058
# 148         Singapore      Asia           78.340     3919300   144363496200
# 163            Taiwan      Asia           76.020    22183000   521855075000

# %%
#for average
df['life_expectancy'].mean()
# Out:
# 66.50153603526596

# %%
#gdp per capita 
#gdp / population
#save it as a column in your df
df['gdp_per_capita'] = df['gdp'] / df['population']
df
# Out:
#                  country   continent  life_expectancy  population  \
# 0            Afghanistan        Asia           54.863    22856302
# 1                Albania      Europe           74.200     3071856
# 2                Algeria      Africa           68.963    30533827
# 3                 Angola      Africa           45.234    13926373
# 4    Antigua and Barbuda  N. America           73.544       77656
# ..                   ...         ...              ...         ...
# 183              Vietnam        Asia           73.777    78758010
# 184   West Bank and Gaza        Asia           70.929     3198560
# 185          Yemen, Rep.        Asia           60.404    17723186
# 186               Zambia      Africa           41.802    10201562
# 187             Zimbabwe      Africa           43.976    12509477
#
#               gdp  gdp_per_capita
# 0     15153728226           663.0
# 1     12886435920          4195.0
# 2    155661450046          5098.0
# ...

# %%
#to have a betetr display of numbers in your df if you want to, ASK chatgpt

# %%
#step 1: take the df
#step 2: filters
#step 3: group by
#step 4: columns
#step 5: the math
df.groupby('continent')['life_expectancy'].median()
#how you read this: the median life expectancy of each continent
# Out:
# continent
# Africa        52.1025
# Asia          70.4275
# Europe        75.5800
# N. America    70.5765
# Oceania       67.4955
# S. America    70.7660
# Name: life_expectancy, dtype: float64

# %%
#you can create a variable with a df only for south america
south_america_df = df[df['continent'] == 'S. America']
south_america_df
# Out:
#        country   continent  life_expectancy  population            gdp  \
# 5    Argentina  S. America           73.822    36930709   390394524839
# 19     Bolivia  S. America           62.994     8307248    28194799712
# 22      Brazil  S. America           70.261   174425387  1405170917672
# 33       Chile  S. America           77.010    15419820   160905821700
# 35    Colombia  S. America           71.026    39764166   228604190334
# 48     Ecuador  S. America           73.353    12345023    69329649168
# 69      Guyana  S. America           63.290      733101     2302670241
# 130   Paraguay  S. America           70.073     5343539    20877206873
# 131       Peru  S. America           70.506    25861887   149766187617
# 158   Suriname  S. America           67.851      466846     2650284742
# 179    Uruguay  S. America           74.777     3319066    30176948072
# 182  Venezuela  S. America           72.432    24348304   229701899936
#
#      gdp_per_capita
# 5           10571.0
# ...

# %%
#problem im going to have is say " df[df['continent'] = 'S. America'] "
# if you accidentally put one "=" instead of "==" it overwrites the dataframe 
# to fix it read the csv again and then run everything until the cell with the mistake

# %%
#how many countries per continent
df['continent'].value_counts()
#df['continent'].count() finds the value and how many times it appears
# Out:
# continent
# Africa        54
# Asia          48
# Europe        42
# N. America    22
# S. America    12
# Oceania       10
# Name: count, dtype: int64

# %%
#see the unique values
df['continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'N. America', 'S. America', 'Oceania'],
#       dtype=object)

# %% [markdown]
# #from homework 01 part 02, we can use pandas

# %%
# !pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.2/3.8 MB 2.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.6/3.8 MB 4.4 MB/s eta 0:00:01
#    --------- ------------------------------ 0.9/3.8 MB 5.4 MB/s eta 0:00:01
#    ------------ --------------------------- 1.2/3.8 MB 6.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.6/3.8 MB 6.3 MB/s eta 0:00:01
#    ------------------- -------------------- 1.9/3.8 MB 6.7 MB/s eta 0:00:01
#    --------------------- ------------------ 2.1/3.8 MB 6.2 MB/s eta 0:00:01
#    ------------------------ --------------- 2.3/3.8 MB 6.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.7/3.8 MB 6.5 MB/s eta 0:00:01
#    -------------------------------- ------- 3.1/3.8 MB 6.6 MB/s eta 0:00:01
#    ------------------------------------ --- 3.5/3.8 MB 6.7 MB/s eta 0:00:01
# ...

# %%
#from homework 01 part 02, we can use pandas
url = "https://www.theguardian.com/football/laligafootball/table"
tables = pd.read_html(url)
tables
#this is a list of dfs that is not shown correctly
#btw this doesnt always works, not all tables in html are written like that
# Out:
# [     P            Team  GP   W   D   L   F   A  GD  Pts  \
#  0    1     Real Madrid  38  29   8   1  87  26  61   95
#  1    2       Barcelona  38  26   7   5  79  44  35   85
#  2    3          Girona  38  25   6   7  85  46  39   81
#  3    4        Atlético  38  24   4  10  70  43  27   76
#  4    5        A Bilbao  38  19  11   8  61  37  24   68
#  5    6   Real Sociedad  38  16  12  10  51  39  12   60
#  6    7      Real Betis  38  14  15   9  48  45   3   57
#  7    8      Villarreal  38  14  11  13  65  65   0   53
#  8    9        Valencia  38  13  10  15  40  45  -5   49
#  9   10          Alaves  38  12  10  16  36  46 -10   46
#  10  11         Osasuna  38  12   9  17  45  56 -11   45
#  11  12          Getafe  38  10  13  15  42  54 -12   43
#  12  13      Celta Vigo  38  10  11  17  46  57 -11   41
#  13  14         Sevilla  38  10  11  17  48  54  -6   41
#  14  15        Mallorca  38   8  16  14  33  44 -11   40
# ...

# %%
len(tables)
# Out:
# 1

# %%
#since it's 1 table we call the one we want, which is zero since one = zero, to show it as a dataframe since we read the html with pandas
df_tables = tables[0]
df_tables
# Out:
#      P            Team  GP   W   D   L   F   A  GD  Pts  \
# 0    1     Real Madrid  38  29   8   1  87  26  61   95
# 1    2       Barcelona  38  26   7   5  79  44  35   85
# 2    3          Girona  38  25   6   7  85  46  39   81
# 3    4        Atlético  38  24   4  10  70  43  27   76
# 4    5        A Bilbao  38  19  11   8  61  37  24   68
# 5    6   Real Sociedad  38  16  12  10  51  39  12   60
# 6    7      Real Betis  38  14  15   9  48  45   3   57
# 7    8      Villarreal  38  14  11  13  65  65   0   53
# 8    9        Valencia  38  13  10  15  40  45  -5   49
# 9   10          Alaves  38  12  10  16  36  46 -10   46
# 10  11         Osasuna  38  12   9  17  45  56 -11   45
# 11  12          Getafe  38  10  13  15  42  54 -12   43
# 12  13      Celta Vigo  38  10  11  17  46  57 -11   41
# 13  14         Sevilla  38  10  11  17  48  54  -6   41
# 14  15        Mallorca  38   8  16  14  33  44 -11   40
# 15  16      Las Palmas  38  10  10  18  33  47 -14   40
# ...

# %%
#ALWAYS WRITE INDEX=FALSE TO NOT SHOW THE INDEX COLUMN WHEN EXPORTING/SAVING OUR DATAFRAME, OTHERWISE IT WILL BE SAVED WITH AN EXTRA COLUMN WITH NUMBERS
df.to_csv("teams.csv", index=False)

# %%
#if i want to read what i saved:
pd.read_csv("teams.csv")
# Out:
#                  country   continent  life_expectancy  population  \
# 0            Afghanistan        Asia           54.863    22856302
# 1                Albania      Europe           74.200     3071856
# 2                Algeria      Africa           68.963    30533827
# 3                 Angola      Africa           45.234    13926373
# 4    Antigua and Barbuda  N. America           73.544       77656
# ..                   ...         ...              ...         ...
# 183              Vietnam        Asia           73.777    78758010
# 184   West Bank and Gaza        Asia           70.929     3198560
# 185          Yemen, Rep.        Asia           60.404    17723186
# 186               Zambia      Africa           41.802    10201562
# 187             Zimbabwe      Africa           43.976    12509477
#
#               gdp  gdp_per_capita
# 0     15153728226           663.0
# 1     12886435920          4195.0
# 2    155661450046          5098.0
# ...

# %% [markdown]
# #from homework / weather api -> we can use pandas

# %%
#what we would do without pandas
import requests

url = "http://api.weatherapi.com/v1/forecast.json?key=1deea713c0524e4abd621042220711&q=London&days=3&aqi=yes&alerts=no"
response = requests.get(url)
data = response.json()
data['forecast']['forecastday']
# Out:
# [{'date': '2024-06-12',
#   'date_epoch': 1718150400,
#   'day': {'maxtemp_c': 15.9,
#    'maxtemp_f': 60.7,
#    'mintemp_c': 7.7,
#    'mintemp_f': 45.8,
#    'avgtemp_c': 12.3,
#    'avgtemp_f': 54.1,
#    'maxwind_mph': 7.4,
#    'maxwind_kph': 11.9,
#    'totalprecip_mm': 1.54,
#    'totalprecip_in': 0.06,
#    'totalsnow_cm': 0.0,
#    'avgvis_km': 9.1,
#    'avgvis_miles': 5.0,
#    'avghumidity': 71,
#    'daily_will_it_rain': 1,
#    'daily_chance_of_rain': 87,
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': 0,
#    'condition': {'text': 'Patchy rain nearby',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#     'code': 1063},
#    'uv': 3.0},
#   'astro': {'sunrise': '04:43 AM',
#    'sunset': '09:18 PM',
#    'moonrise': '10:45 AM',
#    'moonset': '01:03 AM',
#    'moon_phase': 'Waxing Crescent',
#    'moon_illumination': 29,
#    'is_moon_up': 1,
#    'is_sun_up': 0},
#   'hour': [{'time_epoch': 1718146800,
#     'time': '2024-06-12 00:00',
# ...

# %%
#writing it like this is wrong for this api!!!!!!!
pd.DataFrame(data['forecast']['forecastday'])
# Out:
#          date  date_epoch                                                day  \
# 0  2024-06-12  1718150400  {'maxtemp_c': 15.9, 'maxtemp_f': 60.7, 'mintem...
# 1  2024-06-13  1718236800  {'maxtemp_c': 15.8, 'maxtemp_f': 60.5, 'mintem...
# 2  2024-06-14  1718323200  {'maxtemp_c': 18.7, 'maxtemp_f': 65.6, 'mintem...
#
#                                                astro  \
# 0  {'sunrise': '04:43 AM', 'sunset': '09:18 PM', ...
# 1  {'sunrise': '04:43 AM', 'sunset': '09:19 PM', ...
# 2  {'sunrise': '04:42 AM', 'sunset': '09:19 PM', ...
#
#                                                 hour
# 0  [{'time_epoch': 1718146800, 'time': '2024-06-1...
# 1  [{'time_epoch': 1718233200, 'time': '2024-06-1...
# 2  [{'time_epoch': 1718319600, 'time': '2024-06-1...

# %%
#you can use this to make it better for these kind of apis
pd.json_normalize(data['forecast']['forecastday'])
# Out:
#          date  date_epoch                                               hour  \
# 0  2024-06-12  1718150400  [{'time_epoch': 1718146800, 'time': '2024-06-1...
# 1  2024-06-13  1718236800  [{'time_epoch': 1718233200, 'time': '2024-06-1...
# 2  2024-06-14  1718323200  [{'time_epoch': 1718319600, 'time': '2024-06-1...
#
#    day.maxtemp_c  day.maxtemp_f  day.mintemp_c  day.mintemp_f  day.avgtemp_c  \
# 0           15.9           60.7            7.7           45.8           12.3
# 1           15.8           60.5            8.4           47.0           12.2
# 2           18.7           65.6           11.9           53.5           14.6
#
#    day.avgtemp_f  day.maxwind_mph  ...  day.condition.code  day.uv  \
# 0           54.1              7.4  ...                1063     3.0
# 1           54.0             14.3  ...                1063     4.0
# 2           58.3             15.2  ...                1063     6.0
#
#    astro.sunrise  astro.sunset  astro.moonrise  astro.moonset  \
# ...

# %%
pd.json_normalize(data['forecast']['forecastday'][0]['hour'])
# Out:
#     time_epoch              time  temp_c  temp_f  is_day  wind_mph  wind_kph  \
# 0   1718146800  2024-06-12 00:00     8.7    47.7       0       3.4       5.4
# 1   1718150400  2024-06-12 01:00     8.2    46.8       0       3.1       5.0
# 2   1718154000  2024-06-12 02:00     7.9    46.3       0       2.5       4.0
# 3   1718157600  2024-06-12 03:00     7.9    46.2       0       1.8       2.9
# 4   1718161200  2024-06-12 04:00     7.7    45.8       0       1.6       2.5
# 5   1718164800  2024-06-12 05:00     8.5    47.3       1       0.7       1.1
# 6   1718168400  2024-06-12 06:00     9.6    49.3       1       0.4       0.7
# 7   1718172000  2024-06-12 07:00    11.2    52.1       1       1.1       1.8
# 8   1718175600  2024-06-12 08:00    12.2    53.9       1       0.7       1.1
# 9   1718179200  2024-06-12 09:00    13.0    55.5       1       0.9       1.4
# 10  1718182800  2024-06-12 10:00    14.4    57.9       1       2.5       4.0
# ...
